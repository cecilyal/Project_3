# %%
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold

# %%
results_set = pd.read_csv('resultsset2df.csv')

# %%
results_set.drop(['Unnamed: 0'], axis=1)
# Out:
#         _id  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 0     87776 -1.340098 -1.320514 -1.286333 -1.329391 -0.537599 -0.390216
# 1     87777  0.585315 -0.275421  1.604859  0.046554  1.894861 -0.581353
# 2     87778  0.290151  0.076959  0.942821 -0.013861  0.878566  0.275326
# 3     87779 -0.408467  0.011884  1.126055 -0.562285  0.177906  1.183975
# 4     87780 -0.293276  0.006408  0.108143  0.051391  0.476253  0.376401
# 5     87781 -1.546968  1.297895 -0.282891  2.541010 -0.889163  0.150139
# 6     87782 -0.951423  0.148764  0.541746  0.451324 -1.651168  0.609874
# 7     87783  0.239391  0.329704  1.997131 -2.052072  0.099922 -0.863662
# 8     87784 -0.504980  1.124346  0.834462 -1.312148  2.024934 -0.197213
# 9     87785  0.430631  0.962485 -0.424494 -1.077962 -0.004720 -0.962303
# 10    87786 -2.193258 -1.644507  0.085982 -0.057944  1.152360 -1.808383
# 11    87787 -1.841736  0.120615  1.086902 -0.160620  0.173836  0.877746
# ...

# %%
target = results_set['target']
X = results_set.drop(['target'], axis=1)

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression

# %%
def calculate_r2_for_feature(df, model): 
    scores_list = []
    for col in df.columns:
        
        X = df.drop(col, axis = 1)
        y = df[col]
    
        X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.20)
    
    
        regressor = model()
        regressor.fit(X_train, y_train)
    
        score = regressor.score(X_test, y_test)
        scores_list.append(score)
    return scores_list

# %%
results_df = pd.DataFrame(calculate_r2_for_feature(results_set, LogisticRegression))
